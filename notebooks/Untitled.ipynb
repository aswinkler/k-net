# %%
# %run src/train_kan_iris
# Out:
# Entrenando con el dataset Iris, Red: [4, 10, 5,, 3]
# Entrenando capas internas
# Entrenando capas externas
# Entrenando capas internas
# Entrenando capas externas
# Entrenando capas internas
# Entrenando capas externas
# Epoch 000: Loss = 1.1237 | Train Acc = 50.83% | Test Acc = 43.33% | Time =  278418.75 secs
# Entrenando capas internas
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/ExpanDrive/OneDrive/Documents/SWPrj/Python/KANetwork/src/train_kan_iris.py:305
#     302     plot_training_metrics(metrics)
#     304 if __name__ == "__main__":
# --> 305     main()
#
# File ~/ExpanDrive/OneDrive/Documents/SWPrj/Python/KANetwork/src/train_kan_iris.py:301, in main()
#     299 model = KANetwork(layer_dims=[4, 3, 3, 3], knots=knots, activation=relu)
#     300 print ("Entrenando con el dataset Iris, Red: [4, 3, 3,, 3]")
# ...

# %%
# %run src/train_kan_iris
# Out:
# Entrenando con el dataset Iris, Red: [4, 3, 3,, 3]
# Entrenando capas internas
# Entrenando capas externas
# Entrenando capas internas
# Entrenando capas externas
# Entrenando capas internas
# Entrenando capas externas
# Epoch 000: Loss = 1.6457 | Train Acc = 39.17% | Test Acc = 36.67% | Time =  6240.80 secs
# Entrenando capas internas
# Entrenando capas externas
# Entrenando capas internas
# Entrenando capas externas
# Entrenando capas internas
# Entrenando capas externas
# Epoch 001: Loss = 1.5982 | Train Acc = 38.33% | Test Acc = 36.67% | Time =  6226.50 secs
# Entrenando capas internas
# Entrenando capas externas
# Entrenando capas internas
# Entrenando capas externas
# Entrenando capas internas
# Entrenando capas externas
# Epoch 002: Loss = 1.5487 | Train Acc = 38.33% | Test Acc = 36.67% | Time =  6234.56 secs
# Entrenando capas internas
# Entrenando capas externas
# Entrenando capas internas
# Entrenando capas externas
# Entrenando capas internas
# Entrenando capas externas
# ...
