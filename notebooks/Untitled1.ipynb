# %%
# %run src/train_kan_diabetes

# %%
run src/train_kan_diabetes
# Out:
# Entrenando con el dataset Diabetes, Red: [10, 2, 1]
# Entrenando capa interna
# Entrenando capas externas
# Entrenando capa interna
# Entrenando capas externas
# Epoch 000: Loss = 1.4144 | Train RMSE = 1.4144 | Test RMSE = 1.3027 | Time =  11118.83 secs
# Entrenando capa interna
# Entrenando capas externas
# Entrenando capa interna
# Entrenando capas externas
# Epoch 001: Loss = 1.3742 | Train RMSE = 1.3742 | Test RMSE = 1.2769 | Time =  11064.38 secs
# Entrenando capa interna
# Entrenando capas externas
# Entrenando capa interna
# Entrenando capas externas
# Epoch 002: Loss = 1.3164 | Train RMSE = 1.3163 | Test RMSE = 1.2666 | Time =  11107.18 secs
# Entrenando capa interna
# Entrenando capas externas
# Entrenando capa interna
# Entrenando capas externas
# Epoch 003: Loss = 1.2802 | Train RMSE = 1.2802 | Test RMSE = 1.2667 | Time =  11179.76 secs
# Entrenando capa interna
# Entrenando capas externas
# Entrenando capa interna
# Entrenando capas externas
# ...
